# %% [markdown]
# # Data Preparation

# %%
import numpy as np
import pandas as pd
import math
from datetime import datetime, timedelta
import pickle
import re

# show a sample source file size
sample = pd.read_feather("/Users/huilingchen/Documents/GitHub/indeed_web_scraper/source/11_12_2020")
sample.shape
# Out:
# (171, 7)

# %%
# combine all feather file from source folder
import os
import glob

dir_name = "/Users/huilingchen/Documents/GitHub/indeed_web_scraper/source"
os.chdir(dir_name)

all_filenames = [i for i in glob.glob('*')]
combined_source = pd.concat([pd.read_feather(f) for f in all_filenames], ignore_index=True)
combined_source
# Out:
#                                                  Title  \
# 0    Identity and Access Management Support Analyst...
# 1                         Lawson/Infor Systems Analyst
# 2                                     Forecast Analyst
# 3                           Production Support Analyst
# 4                          Corrections Data Analyst II
# ..                                                 ...
# 923                               Sr. Business Analyst
# 924                        Sr Business Analyst (Zelle)
# 925                        Application Support Analyst
# 926               Business Systems Analyst, Salesforce
# 927               Cisco Network Infrastructure Analyst
#
#                         Company                                   Location  \
# 0      Solu Technology Partners                                       None
# 1    Arch Staffing & Consulting                                       None
# 2                Nexeo Plastics                           Dublin, OH 43016
# 3                     Accenture                               Columbus, OH
# 4     JPMorgan Chase Bank, N.A.                               Columbus, OH
# ..                          ...                                        ...
# 923        Yashco Systems, Inc.                         Hilliard, OH 43026
# 924           The Paragon Group                         Columbus, OH 43230
# 925           The Paragon Group                         Columbus, OH 43230
# 926               Veeva Systems  Columbus, OH 43220 (Sawmill Ravines area)
# 927     Crossroads Technologies                               Columbus, OH
#
#                                                   Link  \
# 0    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2    https://www.indeed.com/rc/clk?jk=af3b81fe16665...
# 3    https://www.indeed.com/rc/clk?jk=a19089fc3d9a2...
# 4    https://www.indeed.com/rc/clk?jk=03a530d9989ff...
# ..                                                 ...
# 923  https://www.indeed.com/rc/clk?jk=4ad1929ff49f7...
# 924  https://www.indeed.com/rc/clk?jk=7352307aaa5da...
# 925  https://www.indeed.com/rc/clk?jk=09dbfea9eb940...
# 926  https://www.indeed.com/rc/clk?jk=2477e11410e99...
# 927  https://www.indeed.com/rc/clk?jk=4c0d76714db1b...
#
#                        Salary              Date  \
# 0                        None        10/28/2020
# 1    $80,000 - $90,000 a year        10/28/2020
# 2                        None        10/28/2020
# 3                        None        10/28/2020
# 4                        None        10/28/2020
# ..                        ...               ...
# 923           $103,834 a year  08/30/2020 prior
# 924                      None  08/30/2020 prior
# 925                      None  08/30/2020 prior
# 926                      None  08/30/2020 prior
# 927                      None  08/30/2020 prior
#
#                                            Description
# 0    Title: Identity and Access Management Support ...
# 1    Location: Spokane WA (remote during COVID)\nSa...
# 2    Date: Oct 28, 2020\nLocation: Dublin, OH, US, ...
# 3    Accenture Flex offers you the flexibility of l...
# 4    Position Overview\nCCB Remediation and Correct...
# ..                                                 ...
# 923  Sr. Business Analyst (Multiple Positions with ...
# 924  The Paragon Group is a Columbus, Ohio based In...
# 925  The Paragon Group is a Columbus, Ohio based In...
# 926  At Veeva, we build enterprise cloud technology...
# 927  We are currently seeking experienced technolog...
#
# [928 rows x 7 columns]

# %%
df_indicator = pd.DataFrame()
df_indicator['SAS'] = np.where(combined_source['Description'].str.contains('SAS'), 'True','False')
df_indicator['python'] = np.where(combined_source['Description'].str.contains('python', flags=re.IGNORECASE),'True','False')
df_indicator['SQL'] = np.where(combined_source['Description'].str.contains('spl', flags=re.IGNORECASE),'True','False')
df_indicator['R'] = np.where(combined_source['Description'].str.contains(' R | R,'),'True','False')
df_indicator['excel'] = np.where(combined_source['Description'].str.contains('excel', flags=re.IGNORECASE),'True','False')
df_indicator
# Out:
#        SAS python    SQL      R  excel
# 0    False  False  False  False  False
# 1    False  False  False  False   True
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4     True   True  False   True   True
# ..     ...    ...    ...    ...    ...
# 923  False  False  False  False  False
# 924  False  False  False  False   True
# 925  False  False  False  False   True
# 926  False  False  False  False   True
# 927  False  False  False  False   True
#
# [928 rows x 5 columns]

# %%
percentage = pd.DataFrame()
percentage['sas_percentage'] = df_indicator['SAS'].value_counts(normalize=True) * 100 
percentage['python_percentage'] = df_indicator['python'].value_counts(normalize=True) * 100 
percentage['excel_percentage'] = df_indicator['excel'].value_counts(normalize=True) * 100 
percentage['R_percentage'] = df_indicator['R'].value_counts(normalize=True) * 100 
percentage['sql_percentage'] = df_indicator['SQL'].value_counts(normalize=True) * 100 
percentage
# Out:
#        sas_percentage  python_percentage  excel_percentage  R_percentage  \
# False       95.689655          91.918103         39.978448     96.551724
# True         4.310345           8.081897         60.021552      3.448276
#
#        sql_percentage
# False       95.043103
# True         4.956897

# %%
import seaborn as sns
import matplotlib.pyplot as plt
 
# read a titanic.csv file
# from seaborn libraray
df = sns.load_dataset(percentage)
 
# who v/s fare barplot 
sns.barplot(x = 'tool',
            y = 'usage',
            data = df)
 
# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-25f7c17c948e> in <module>
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#       3
#       4 # read a titanic.csv file
#       5 # from seaborn libraray
#
# ModuleNotFoundError: No module named 'seaborn'
